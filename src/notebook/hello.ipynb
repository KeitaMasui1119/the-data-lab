# %% [markdown]
# # LaTeXの書き方
#
# ## 問題1：2次方程式の解
# 以下の2次方程式を考える：
#
# $$
# ax^2 + bx + c = 0
# $$
#
# この方程式の解は、判別式 $D = b^2 - 4ac$ を用いて以下のように表される：
#
# $$
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# $$
#
# ---
#
# ## 問題2：定積分の計算
# 次の定積分を計算せよ：
#
# $$
# \int_{0}^{1} x^2 dx
# $$
#
# **解答**：
#
# $$
# \int_{0}^{1} x^2 dx = \left[ \frac{1}{3}x^3 \right]_0^1 = \frac{1}{3}
# $$
#
# ---
#
# ## 問題3：線形代数
# 次の連立一次方程式を行列の形で表現し、解を求めよ：
#
# $$
# \begin{aligned}
# 2x + y &= 5 \\
# 3x - 2y &= -4
# \end{aligned}
# $$
#
# 行列形式で書くと：
#
# $$
# \begin{bmatrix}
# 2 & 1 \\
# 3 & -2
# \end{bmatrix}
# \begin{bmatrix}
# x \\
# y
# \end{bmatrix}
# =
# \begin{bmatrix}
# 5 \\
# -4
# \end{bmatrix}
# $$
#
# ガウスの消去法等で解が求まる。

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# ダミーデータの生成
# 実際のデータに置き換えることができます
np.random.seed(42)
dates = pd.date_range(start="2024-01-01", periods=100, freq="D")
y_data = np.random.randn(100).cumsum() + 50

# データフレームの作成
df = pd.DataFrame({'Date': dates, 'Value': y_data})

# Plotlyのグラフオブジェクトを生成
# go.Scatterは折れ線グラフを作成するためのクラスです
fig = go.Figure(
    data=go.Scatter(
        x=df['Date'],
        y=df['Value'],
        mode='lines+markers',
        name='日次データ'
    )
)

# グラフのレイアウトをカスタマイズ
fig.update_layout(
    title='Plotlyを使用した日次データの折れ線グラフ',
    xaxis_title='日付',
    yaxis_title='値',
    hovermode='x unified'
)

# グラフをJupyter Notebookに表示
# .show()メソッドは、グラフをブラウザでインタラクティブに表示します
fig.show()

# %%
import matplotlib.pyplot as plt
import japanize_matplotlib
import pandas as pd
import numpy as np

# ダミーデータの生成
# 実際のデータに置き換えることができます
np.random.seed(42)
dates = pd.date_range(start="2024-01-01", periods=100, freq="D")
y_data = np.random.randn(100).cumsum() + 50

# データフレームの作成
df = pd.DataFrame({'Date': dates, 'Value': y_data})

# プロットの作成
plt.figure(figsize=(10, 6))  # グラフのサイズを設定
plt.plot(df['Date'], df['Value'], marker='o', linestyle='-')

# グラフのカスタマイズ
plt.title('Matplotlibを使用した日次データの折れ線グラフ', fontsize=16)
plt.xlabel('日付', fontsize=12)
plt.ylabel('値', fontsize=12)
plt.grid(True)  # グリッド線を表示
plt.xticks(rotation=45) # X軸のラベルを45度回転させて見やすくする
plt.tight_layout() # レイアウトを調整

# グラフの表示
plt.show()

# %%
# セル1: 必要なライブラリのインポート
# データ操作と可視化のために、Pandas, NumPy, Matplotlibをインポートします。

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import japanize_matplotlib

print("ライブラリのインポートが完了しました。")

# ---

# セル2: ダミーデータの生成と表示
# 複数の列を持つDataFrameを作成し、最初の数行を表示します。

np.random.seed(42)  # 再現性のためのシード設定
data = {
    'city': np.random.choice(['Tokyo', 'Osaka', 'Nagoya'], 1000),
    'temperature': np.random.normal(loc=25, scale=5, size=1000),
    'humidity': np.random.normal(loc=60, scale=10, size=1000),
    'rainfall_mm': np.random.exponential(scale=5, size=1000),
    'date': pd.date_range(start='2024-01-01', periods=1000, freq='D')
}

df = pd.DataFrame(data)

print("生成されたDataFrameの最初の5行:")
print(df.head())
print("\nDataFrameの情報:")
df.info()

# ---

# セル3: 基本的な統計分析
# DataFrameの要約統計量を手動で計算し、カテゴリ別の平均値を算出します。

# 全体の統計量
print("全体の統計量:")
print(f"平均気温: {df['temperature'].mean():.2f}")
print(f"気温の中央値: {df['temperature'].median():.2f}")
print(f"気温の標準偏差: {df['temperature'].std():.2f}")
print(f"最大降雨量: {df['rainfall_mm'].max():.2f}")
print(f"最小湿度: {df['humidity'].min():.2f}")

# 都市別の統計量
print("\n都市別の平均気温と湿度:")
city_stats = df.groupby('city')[['temperature', 'humidity']].mean()
print(city_stats)

# ---

# セル4: データの可視化 (Matplotlibのみ)
# 複数の種類のグラフを作成して、データの関係性を探ります。

# 散布図: 気温と湿度の関係
plt.figure(figsize=(10, 6))
# 都市ごとにデータを分割してプロット
for city in df['city'].unique():
    subset = df[df['city'] == city]
    plt.scatter(subset['temperature'], subset['humidity'], label=city, alpha=0.7)

plt.title('気温と湿度の関係 (都市別)', fontsize=16)
plt.xlabel('気温 (°C)', fontsize=12)
plt.ylabel('湿度 (%)', fontsize=12)
plt.legend(title='都市')
plt.grid(True)
plt.show()

# ヒストグラム: 降雨量の分布
plt.figure(figsize=(10, 6))
plt.hist(df['rainfall_mm'], bins=30, edgecolor='black')
plt.title('降雨量の分布', fontsize=16)
plt.xlabel('降雨量 (mm)', fontsize=12)
plt.ylabel('頻度', fontsize=12)
plt.grid(axis='y', alpha=0.75)
plt.show()

# ---

# セル5: ファイルの読み書き
# DataFrameをCSVファイルに保存し、再度読み込みます。

file_path = '/workspaces/my-python-devcontainer/data/csv/weather_data_no_ss.csv'
df.to_csv(file_path, index=False)
print(f"DataFrameを'{file_path}'に保存しました。")

# 保存したファイルを読み込む
df_loaded = pd.read_csv(file_path)

print(f"\n'{file_path}'から読み込んだDataFrameの最初の5行:")
print(df_loaded.head())

print("\nデータの整合性を確認...")
if df.equals(df_loaded):
    print("データは正常に保存・読み込みされました。")
else:
    print("データの整合性に問題があります。")
# Out:
# ライブラリのインポートが完了しました。
# 生成されたDataFrameの最初の5行:
#      city  temperature   humidity  rainfall_mm       date
# 0  Nagoya    25.242608  60.884069     2.207166 2024-01-01
# 1   Tokyo    20.845249  74.775301     2.183147 2024-01-02
# 2  Nagoya    26.352284  48.583109     8.817481 2024-01-03
# 3  Nagoya    24.748809  58.063405     7.786430 2024-01-04
# 4   Tokyo    23.805260  52.831777     1.839372 2024-01-05
#
# DataFrameの情報:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   city         1000 non-null   object
#  1   temperature  1000 non-null   float64
#  2   humidity     1000 non-null   float64
#  3   rainfall_mm  1000 non-null   float64
#  4   date         1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 39.2+ KB
# 全体の統計量:
# 平均気温: 25.36
# 気温の中央値: 25.31
# 気温の標準偏差: 4.96
# 最大降雨量: 38.62
# 最小湿度: 29.80
#
# 都市別の平均気温と湿度:
#         temperature   humidity
# city
# Nagoya    25.218301  60.370537
# Osaka     25.349524  59.604596
# Tokyo     25.485448  60.404238
# DataFrameを'weather_data_no_ss.csv'に保存しました。
#
# 'weather_data_no_ss.csv'から読み込んだDataFrameの最初の5行:
#      city  temperature   humidity  rainfall_mm        date
# 0  Nagoya    25.242608  60.884069     2.207166  2024-01-01
# 1   Tokyo    20.845249  74.775301     2.183147  2024-01-02
# 2  Nagoya    26.352284  48.583109     8.817481  2024-01-03
# 3  Nagoya    24.748809  58.063405     7.786430  2024-01-04
# 4   Tokyo    23.805260  52.831777     1.839372  2024-01-05
#
# データの整合性を確認...
# データの整合性に問題があります。
